# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import scipy

# %%
data = pd.read_csv('dataset/epa-sea-level.csv')

# %%
data.isnull().sum()
# Out:
# Year                          0
# CSIRO Adjusted Sea Level      0
# Lower Error Bound             0
# Upper Error Bound             0
# NOAA Adjusted Sea Level     113
# dtype: int64

# %%
data
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
fig1 , ax1 = plt.subplots(figsize= (10,6))

ax1.scatter(x=data['Year'], y=data['CSIRO Adjusted Sea Level'])


fig1.show()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_67364\2677287136.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()

# %%
res = scipy.stats.linregress(x=data['Year'], y=data['CSIRO Adjusted Sea Level'])

# %%
future = np.arange(2000,2050)

fig2, ax2 = plt.subplots(figsize=(10,6))

ax2.scatter(x=data['Year'], y=data['CSIRO Adjusted Sea Level'])
ax2.plot(data['Year'], res.intercept + res.slope*data['Year'], 'r')
ax2.plot(future, res.intercept + res.slope*future, 'g')

ax2.set_title('Sea Level')
ax2.set_xlabel('Year')
ax2.set_ylabel('Sea Level (inches)')
ax2.legend()

fig2.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_67364\322490712.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()

# %%
new_data = data[data['Year'] >= 2000]

# %%
new_res = scipy.stats.linregress(x=new_data['Year'], y=new_data['CSIRO Adjusted Sea Level'])

# %%
fig3, ax3 = plt.subplots(figsize=(10,6))

ax3.scatter(new_data['Year'], new_data['CSIRO Adjusted Sea Level'])
ax3.plot(future, new_res.intercept + new_res.slope*future, 'g')

ax3.set_title('Sea Level')
ax3.set_xlabel('Year')
ax3.set_ylabel('Sea Level (inches)')
ax3.legend()

fig3.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_67364\939502967.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig3.show()
